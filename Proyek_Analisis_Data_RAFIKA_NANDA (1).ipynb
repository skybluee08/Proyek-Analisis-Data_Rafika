# %% [markdown]
# # Proyek Analisis Data: Bike Sharing Dataset
# - **Nama:** Rafika Nanda Agustina
# - **Email:** rafika.22105@mhs.unesa.ac.id
# - **ID Dicoding:** rafikananda

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana pengaruh cuaca terhadap jumlah total pengguna sepeda pada hari kerja?
# - Bagaimana hubungan antara jumlah pengguna sepeda pada setiap jam?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Load tabel day
day_df=pd.read_csv("day.csv")
day_df.head()
# Akan menampilkan 5 baris pertama dari DataFrame day_df
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Load tabel hour
hour_df=pd.read_csv("hour.csv")
hour_df.head()
# Akan menampilkan 5 baris pertama dari DataFrame hour_df
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# **Insight:**
# - Kita mengetahui bahwa pada tabel data day terdapat 16 kolom dan pada tabel data hour terdapat 17 kolom

# %% [markdown]
# ### Assessing Data

# %%
# Menilai data day_df
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
# Menilai data hour_df
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %% [markdown]
# **Insight:**
# - Kita mengetahui bahwa terdapat kesalahan tipe data untuk kolom dteday pada tabel day_df dan hour_df

# %% [markdown]
# ### Cleaning Data

# %%
# Membersihkan data day_df
column="dteday"
day_df[column]=pd.to_datetime(day_df[column])

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB

# %%
# Membersihkan data hour_df
column="dteday"
hour_df[column]=pd.to_datetime(hour_df[column])

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  datetime64[ns]
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: datetime64[ns](1), float64(4), int64(12)
# memory usage: 2.3 MB

# %% [markdown]
# **Insight:**
# - Kita berhasil membersihkan kesalahan tipe data object menjadi datetime di kolom dteday pada tabel day_df dan hour_df

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Eksplorasi Data day_df

# %%
# Menampilkan rangkuman parameter statistik pada day_df
day_df.describe(include="all")
# Out:
#           instant               dteday      season          yr        mnth  \
# count  731.000000                  731  731.000000  731.000000  731.000000
# mean   366.000000  2012-01-01 00:00:00    2.496580    0.500684    6.519836
# min      1.000000  2011-01-01 00:00:00    1.000000    0.000000    1.000000
# 25%    183.500000  2011-07-02 12:00:00    2.000000    0.000000    4.000000
# 50%    366.000000  2012-01-01 00:00:00    3.000000    1.000000    7.000000
# 75%    548.500000  2012-07-01 12:00:00    3.000000    1.000000   10.000000
# max    731.000000  2012-12-31 00:00:00    4.000000    1.000000   12.000000
# std    211.165812                  NaN    1.110807    0.500342    3.451913
#
#           holiday     weekday  workingday  weathersit        temp       atemp  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.028728    2.997264    0.683995    1.395349    0.495385    0.474354
# ...

# %%
# Menampilkan hubungan antara weathersit, workingday, dan total pengguna
day_df.groupby(by=["weathersit", "workingday"]).agg({"instant":"nunique",
    "cnt":["sum", "max", "min", "mean", "std"]})
# Out:
#                       instant      cnt
#                       nunique      sum   max  min         mean          std
# weathersit workingday
# 1          0              156   715614  8714  754  4587.269231  2047.547484
#            1              307  1542338  8173  431  5023.902280  1773.485099
# 2          0               70   275578  7852  605  3936.828571  1925.475601
#            1              177   721280  8362  683  4075.028249  1765.122364
# 3          0                5     9077  4459  627  1815.400000  1595.990226
#            1               16    28792  4639   22  1799.500000  1171.221812

# %%
# Menampilkan rangkuman parameter statistik hour_df
hour_df.describe(include="all")
# Out:
#           instant                         dteday        season            yr  \
# count  17379.0000                          17379  17379.000000  17379.000000
# mean    8690.0000  2012-01-02 04:08:34.552045568      2.501640      0.502561
# min        1.0000            2011-01-01 00:00:00      1.000000      0.000000
# 25%     4345.5000            2011-07-04 00:00:00      2.000000      0.000000
# 50%     8690.0000            2012-01-02 00:00:00      3.000000      1.000000
# 75%    13034.5000            2012-07-02 00:00:00      3.000000      1.000000
# max    17379.0000            2012-12-31 00:00:00      4.000000      1.000000
# std     5017.0295                            NaN      1.106918      0.500008
#
#                mnth            hr       holiday       weekday    workingday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       6.537775     11.546752      0.028770      3.003683      0.682721
# ...

# %%
# Menampilkan hubungan antara jam-jam dengan total pengguna
hour_df.groupby(by="hr").agg({"instant":"nunique",
    "cnt": ["sum", "max", "min", "mean", "std"]})
# Out:
#    instant     cnt
#    nunique     sum  max min        mean         std
# hr
# 0      726   39130  283   2   53.898072   42.307910
# 1      724   24164  168   1   33.375691   33.538727
# 2      715   16352  132   1   22.869930   26.578642
# 3      697    8174   79   1   11.727403   13.239190
# 4      697    4428   28   1    6.352941    4.143818
# 5      717   14261   66   1   19.889819   13.200765
# 6      725   55132  213   1   76.044138   55.084348
# 7      727  154171  596   1  212.064649  161.441936
# 8      727  261001  839   5  359.011004  235.189285
# 9      727  159438  426  14  219.309491   93.703458
# 10     727  126257  539   8  173.668501  102.205413
# 11     727  151320  663  10  208.143054  127.495536
# 12     728  184414  776   3  253.315934  145.081134
# 13     729  184919  760  11  253.661180  148.107657
# 14     729  175652  750  12  240.949246  147.271574
# 15     729  183149  750   7  251.233196  144.632541
# 16     730  227748  783  11  311.983562  148.682618
# ...

# %%
# Menambahkan kolom categories yang berisi pembagian jam menjadi malam hari, pagi hari, siang hari, sore hari, dan malam hari
hour_df["categories"]=hour_df.hr.apply(lambda x: "Pagi Hari" if x>=5 and x<11
                                       else ("Siang Hari" if x>=11 and x<15
                                             else "Sore Hari" if x>=15 and x<20
                                             else "Malam Hari"))
hour_df.groupby(by="categories").instant.nunique().sort_values(ascending=False)
# Out:
# categories
# Malam Hari    6471
# Pagi Hari     4350
# Sore Hari     3645
# Siang Hari    2913
# Name: instant, dtype: int64

# %%
# Menampilkan hubungan categories dengan total pengguna
hour_df.groupby(by="categories").agg({"instant":"nunique",
                                      "cnt":["sum", "max", "min", "std"]})
# Out:
#            instant      cnt
#            nunique      sum  max min         std
# categories
# Malam Hari    6471   541796  584   1   95.889598
# Pagi Hari     4350   770260  839   1  170.707697
# Siang Hari    2913   696305  776   3  143.378613
# Sore Hari     3645  1284318  977   7  202.068075

# %% [markdown]
# **Insight:**
# - Pada eksplorasi data day_df menampilkan analisis pengaruh cuaca terhadap jumlah pengguna dimana pada cuaca 4 sama sekali tidak ada pengguna sepeda.
# - Pada Eksplorasi data hour_df menampilkan analisis pengaruh waktu terhadap jumlah pengguna dimana pengguna sepeda paling banyak di sore hari.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana pengaruh cuaca terhadap jumlah total pengguna sepeda pada hari kerja?

# %%
weather_workingday_df=day_df[day_df["workingday"]==1].groupby(["weathersit"]).cnt.sum().sort_values(ascending=False).reset_index()
# Pada bagian sebelumnya, didapat bahwa di cuaca 4 tidak ada pengguna sepeda, maka kita akan menambahkan cuaca 4 dengan jumlah pengguna 0.
if not (weather_workingday_df["weathersit"]==4).any():
  new_row = pd.DataFrame({"weathersit": [4], "cnt":[0]})
  weather_workingday_df=pd.concat([weather_workingday_df, new_row], ignore_index=True)

weather_workingday_df.rename(columns={"weathersit":"weather_index", "cnt": "users_count"}, inplace=True)

weather_workingday_df.head()
# Out:
#    weather_index  users_count
# 0              1      1542338
# 1              2       721280
# 2              3        28792
# 3              4            0

# %%
fig, ax = plt.subplots()
labels_detail = [
    'Clear or Partly cloudy',
    'Mist and/or Cloudy',
    'Light Rain and/or Thunderstorm or Light Snow', 'Heavy Rain or Snow and Fog'
]
size = weather_workingday_df["users_count"]
colors = ['#ff9999', '#ffcc99', '#99ccff', '#c2c2f0']
pie = plt.pie(size, startangle=0, colors=colors)
title = plt.title("Jumlah Pengguna Sepeda di Setiap Cuaca\nPada Hari Bekerja Pada 2011-2012", fontsize=17)
title.set_ha("center")
plt.legend(
    pie[0],
    labels_detail,
    bbox_to_anchor=(0.65,-0.05),
    loc="lower right",
    bbox_transform=plt.gcf().transFigure
)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Bagaimana hubungan antara jumlah pengguna sepeda pada setiap jam?

# %%
byHourGroup_df = hour_df.groupby(by="categories").cnt.sum().reset_index()
byHourGroup_df.rename(columns={
    "categories": "Waktu",
    "cnt": "Pengguna"
}, inplace=True)
byHourGroup_df.head()
# Out:
#         Waktu  Pengguna
# 0  Malam Hari    541796
# 1   Pagi Hari    770260
# 2  Siang Hari    696305
# 3   Sore Hari   1284318

# %%
plt.figure(figsize=(10, 5))
custom_colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#ffb142']
sns.barplot(
    y="Pengguna",
    x="Waktu",
    hue="Waktu",
    data=byHourGroup_df.sort_values(by="Pengguna", ascending=False),
    palette=custom_colors, legend=False
)
plt.title("Jumlah Total Pengguna di Setiap Kelompok Jam", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='x', labelsize=12)
plt.show()
# Out:
# <ipython-input-19-1eb1f4a86439>:3: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.barplot(
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# **Insight:**
# - Pada Visualisasi pertanyaan 1 dapat dilihat bahwa faktor cuaca mempengaruhi jumlah penguna sepeda, pengguna sepeda paling banyak ketika cuaca cerah dan paling sedikit pada cuaca hujan lebat atau salju dan kabut.
# - Pada Visualisasi pertanyaan 2 dapat dilihat bahwa jam juga memepengaruhi jumlah pengguna sepeda, pengguna sepeda paling banyak pada waktu sore hari pukul 15 sampai maksimal pukul 20, sedangkan pengguna sepeda paling sedikit pada waktu malam hari pukul 20 sampai sebelum pukul 5 pagi.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - **Conclution pertanyaan 1**: Berdasarkan analisis yang dilakukan dapat disimpulkan bahwa cuaca mempengaruhi jumlah pengguna sepeda pada hari kerja, pengguna sepeda paling banyak ketika cuaca cerah atau berawan sebagian, pengguna terbanyak kedua saat cuaca kabut atau berawan, pengguna terbanyak ketiga ketika cuaca hujan ringan, dan pengguna sepeda paling sedikit ketika hujan lebat.
# - **Conclution pertanyaan 2**:Berdasarkan analisis yang dilakukan dapar disimpulkan bahwa terdapat hubungan antara jam dengan jumlah pengguna sepeda, pengguna sepeda paling banyak pada waktu sore hari, pengguna sepeda terbanyak kedua pada waktu pagi hari, pengguna sepeda ketiga terbanyak pada waktu siang hai, dan pengguna sepeda paling sedikit adalah di waktu malam hari.(kategori waktu tertera di tabel atas)
